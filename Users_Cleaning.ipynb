# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re

# %%
url1="https://raw.githubusercontent.com/kushalpoddar/idyll-dummy-dataset/main/users.csv"
url2="https://raw.githubusercontent.com/kushalpoddar/idyll-dummy-dataset/main/swipes.csv"

# %%
users=pd.read_csv(url1)
users.set_index("_id",inplace=True)

# %%
swipes=pd.read_csv(url2,low_memory=False)

# %%
users.head()
# Out:
#                                                    bio  \
# _id
# 0                   I am very honest and caring person
# 1                                  Let's go on a date.
# 2                                          Loving life
# 3    Jai Maharashtra\n🥲Bharat Mata ki Jay.....\nInq...
# 4                                                    🙄
#
#                              college country                 createdAt  \
# _id
# 0    ["Jawaharlal Nehru University"]      IN  2023-02-07T05:23:18.004Z
# 1                      ["Heritage "]      IN  2023-02-07T05:44:15.450Z
# 2    ["Jawaharlal Nehru University"]      IN  2023-02-07T05:57:29.233Z
# 3    ["Jawaharlal Nehru University"]      IN  2023-02-07T06:04:39.836Z
# 4    ["Jawaharlal Nehru University"]      IN  2023-02-07T07:05:14.605Z
#
#                           dob                 email  \
# _id
# 0    2002-07-16T00:00:00.000Z  9000000000@get.idyll
# 1    1999-02-26T00:00:00.000Z  9100000000@get.idyll
# 2    2001-01-08T00:00:00.000Z  9200000000@get.idyll
# 3    2000-08-20T00:00:00.000Z  9300000000@get.idyll
# 4    2000-07-31T00:00:00.000Z  9400000000@get.idyll
#
#                           face_detection_probabilities gender  height  \
# _id
# 0                                   [90.7028079032898]      M   175.0
# 1                                                   []      M   177.0
# 2                                  [88.67224454879761]      F   175.0
# 3    [90.63367247581482,70.43942511081696,96.189951...      M   177.0
# 4                                                  NaN      M   178.0
#
#      insta_username  ... is_verified      mobile               name status  \
# _id                  ...
# 0               NaN  ...        True  9000000000     Prakhar Sharma   True
# 1               NaN  ...        True  9100000000               Amit   True
# 2               NaN  ...        True  9200000000               Ritz   True
# 3               NaN  ...        True  9300000000     Devesh Shukla    True
# 4               NaN  ...       False  9400000000  Aditya bhadoriya    True
#
#      type                 updatedAt               verified_at what_to_find  \
# _id
# 0       U  2023-02-22T11:57:08.616Z  2023-02-22T11:57:04.347Z            C
# 1       U  2023-02-21T18:07:44.286Z  2023-02-21T18:01:34.165Z            C
# 2       U  2023-02-14T10:33:13.373Z                       NaN            R
# 3       U  2023-02-26T20:28:11.956Z                       NaN            R
# 4       U  2023-02-07T07:09:17.627Z                       NaN           NS
#
#     who_to_date is_subscribed
# _id
# 0             F          True
# 1             F          True
# 2             M          True
# 3             F          True
# 4             A           NaN
#
# [5 rows x 23 columns]

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1405 entries, 0 to 1404
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bio                           1076 non-null   object
#  1   college                       1403 non-null   object
#  2   country                       1405 non-null   object
#  3   createdAt                     1405 non-null   object
#  4   dob                           1192 non-null   object
#  5   email                         1405 non-null   object
#  6   face_detection_probabilities  765 non-null    object
#  7   gender                        1258 non-null   object
#  8   height                        646 non-null    float64
#  9   insta_username                0 non-null      float64
#  10  interests                     1403 non-null   object
#  11  is_habit_drink                883 non-null    object
#  12  is_habit_smoke                880 non-null    object
#  13  is_verified                   1404 non-null   object
#  14  mobile                        1405 non-null   int64
#  15  name                          1261 non-null   object
#  16  status                        1405 non-null   bool
#  17  type                          1405 non-null   object
#  18  updatedAt                     1405 non-null   object
#  19  verified_at                   178 non-null    object
#  20  what_to_find                  884 non-null    object
#  21  who_to_date                   1190 non-null   object
#  22  is_subscribed                 557 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(19)
# memory usage: 253.8+ KB

# %%
swipes.head()
# Out:
#    id      first_like_unlike_at first_msg first_type  is_unmatch  like_count  \
# 0   0  2023-02-07T06:12:59.013Z       NaN    DISLIKE       False           2
# 1   1  2023-02-07T06:13:04.999Z       NaN    DISLIKE       False           1
# 2   2  2023-02-07T06:13:10.206Z       NaN    DISLIKE       False           2
# 3   3  2023-02-07T07:10:01.566Z       NaN    DISLIKE       False           1
# 4   4  2023-02-07T07:10:04.391Z       NaN    DISLIKE       False           1
#
#    p1 p1_extend_at  p2 p2_extend_at     second_like_unlike_at second_msg  \
# 0   2          NaN   0          NaN  2023-02-07T11:15:48.194Z        NaN
# 1   2          NaN   1          NaN                       NaN        NaN
# 2   2          NaN   3          NaN  2023-02-07T11:58:49.136Z        NaN
# 3   4          NaN   0          NaN                       NaN        NaN
# 4   4          NaN   1          NaN                       NaN        NaN
#
#   second_type unmatch_on
# 0     DISLIKE        NaN
# 1         NaN        NaN
# 2        LIKE        NaN
# 3         NaN        NaN
# 4         NaN        NaN

# %% [markdown]
# # Cleaning

# %%
users_relevant = ['createdAt', 'gender', 'interests' , 'is_verified','status','updatedAt','who_to_date']

# %%
users_df = users[users_relevant]

# %%
users_df
# Out:
#                      createdAt gender  \
# _id
# 0     2023-02-07T05:23:18.004Z      M
# 1     2023-02-07T05:44:15.450Z      M
# 2     2023-02-07T05:57:29.233Z      F
# 3     2023-02-07T06:04:39.836Z      M
# 4     2023-02-07T07:05:14.605Z      M
# ...                        ...    ...
# 1400  2023-03-03T09:53:01.297Z      M
# 1401  2023-03-03T12:43:15.149Z      M
# 1402  2023-03-03T12:43:15.633Z      M
# 1403  2023-03-03T16:12:31.677Z      M
# 1404  2023-03-03T17:52:52.405Z      M
#
#                                               interests is_verified  status  \
# _id
# 0     ["Art & Craft","Bollywood","Comedy","Design","...        True    True
# 1     ["Singing","Writing","Dancing","Mountains","Bi...        True    True
# 2     ["Badminton","Design","Writing","Open-Minded",...        True    True
# 3     ["Singing","Cricket","Concerts","Vegetarian","...        True    True
# 4       ["Football","Gym","Biryani","Sci-fi","Cricket"]       False    True
# ...                                                 ...         ...     ...
# 1400                ["Documentaries","Reels","Dancing"]       False    True
# 1401                              ["Rock","Vegetarian"]       False    True
# 1402  ["Bollywood","EDM","Coffee","Football","Biryani"]       False    True
# 1403                                                 []       False    True
# 1404  ["Running","Swimming","Stand Up","Biryani","EDM"]       False    True
#
#                      updatedAt who_to_date
# _id
# 0     2023-02-22T11:57:08.616Z           F
# 1     2023-02-21T18:07:44.286Z           F
# 2     2023-02-14T10:33:13.373Z           M
# 3     2023-02-26T20:28:11.956Z           F
# 4     2023-02-07T07:09:17.627Z           A
# ...                        ...         ...
# 1400  2023-03-03T09:58:15.338Z           F
# 1401  2023-03-03T15:30:05.813Z           F
# 1402  2023-03-03T15:10:17.314Z           F
# 1403  2023-03-03T16:22:51.150Z           F
# 1404  2023-03-03T17:57:27.400Z           F
#
# [1405 rows x 7 columns]

# %%
users_df["interests"][0]
# Out:
# '["Art & Craft","Bollywood","Comedy","Design","Badminton"]'

# %%
users_df.isnull().sum()
# Out:
# createdAt        0
# gender         147
# interests        2
# is_verified      1
# status           0
# updatedAt        0
# who_to_date    215
# dtype: int64

# %%
users_df['status'].sum()
# Out:
# 1113

# %%
users_df  = users_df.drop(users_df[users_df.status==False].index)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1113 entries, 0 to 1404
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   createdAt    1113 non-null   object
#  1   gender       993 non-null    object
#  2   interests    1113 non-null   object
#  3   is_verified  1113 non-null   object
#  4   status       1113 non-null   bool
#  5   updatedAt    1113 non-null   object
#  6   who_to_date  961 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 62.0+ KB

# %%
users_df.isnull().sum()
# Out:
# createdAt        0
# gender         120
# interests        0
# is_verified      0
# status           0
# updatedAt        0
# who_to_date    152
# dtype: int64

# %%
users_df  = users_df [users_df ['gender'].notna()]

# %%
users_df.isnull().sum()
# Out:
# createdAt       0
# gender          0
# interests       0
# is_verified     0
# status          0
# updatedAt       0
# who_to_date    32
# dtype: int64

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 993 entries, 0 to 1404
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   createdAt    993 non-null    object
#  1   gender       993 non-null    object
#  2   interests    993 non-null    object
#  3   is_verified  993 non-null    object
#  4   status       993 non-null    bool
#  5   updatedAt    993 non-null    object
#  6   who_to_date  961 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 55.3+ KB

# %%
users_df['who_to_date'].fillna("A", inplace = True)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 993 entries, 0 to 1404
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   createdAt    993 non-null    object
#  1   gender       993 non-null    object
#  2   interests    993 non-null    object
#  3   is_verified  993 non-null    object
#  4   status       993 non-null    bool
#  5   updatedAt    993 non-null    object
#  6   who_to_date  993 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 55.3+ KB

# %%
users_df.head()
# Out:
#                     createdAt gender  \
# _id
# 0    2023-02-07T05:23:18.004Z      M
# 1    2023-02-07T05:44:15.450Z      M
# 2    2023-02-07T05:57:29.233Z      F
# 3    2023-02-07T06:04:39.836Z      M
# 4    2023-02-07T07:05:14.605Z      M
#
#                                              interests is_verified  status  \
# _id
# 0    ["Art & Craft","Bollywood","Comedy","Design","...        True    True
# 1    ["Singing","Writing","Dancing","Mountains","Bi...        True    True
# 2    ["Badminton","Design","Writing","Open-Minded",...        True    True
# 3    ["Singing","Cricket","Concerts","Vegetarian","...        True    True
# 4      ["Football","Gym","Biryani","Sci-fi","Cricket"]       False    True
#
#                     updatedAt who_to_date
# _id
# 0    2023-02-22T11:57:08.616Z           F
# 1    2023-02-21T18:07:44.286Z           F
# 2    2023-02-14T10:33:13.373Z           M
# 3    2023-02-26T20:28:11.956Z           F
# 4    2023-02-07T07:09:17.627Z           A

# %%
def format_interests(s):
  return re.sub("\"|\[|\]", "", s)

users_df['interests'] = users_df.interests.apply(lambda x: format_interests(str(x)))

# %%
users_df.head()
# Out:
#                     createdAt gender  \
# _id
# 0    2023-02-07T05:23:18.004Z      M
# 1    2023-02-07T05:44:15.450Z      M
# 2    2023-02-07T05:57:29.233Z      F
# 3    2023-02-07T06:04:39.836Z      M
# 4    2023-02-07T07:05:14.605Z      M
#
#                                          interests is_verified  status  \
# _id
# 0    Art & Craft,Bollywood,Comedy,Design,Badminton        True    True
# 1        Singing,Writing,Dancing,Mountains,Biryani        True    True
# 2      Badminton,Design,Writing,Open-Minded,Coffee        True    True
# 3          Singing,Cricket,Concerts,Vegetarian,Tea        True    True
# 4              Football,Gym,Biryani,Sci-fi,Cricket       False    True
#
#                     updatedAt who_to_date
# _id
# 0    2023-02-22T11:57:08.616Z           F
# 1    2023-02-21T18:07:44.286Z           F
# 2    2023-02-14T10:33:13.373Z           M
# 3    2023-02-26T20:28:11.956Z           F
# 4    2023-02-07T07:09:17.627Z           A

# %%
users_df[users_df.index==170]
# Out:
#                     createdAt gender  \
# _id
# 170  2023-02-08T15:48:00.207Z      F
#
#                                          interests is_verified  status  \
# _id
# 170  Anime,Manga,LGBTQIA+ ally,Singing,Open-Minded       False    True
#
#                     updatedAt who_to_date
# _id
# 170  2023-02-08T15:53:52.457Z           M

# %%
users_df.head()
# Out:
#                     createdAt gender  \
# _id
# 0    2023-02-07T05:23:18.004Z      M
# 1    2023-02-07T05:44:15.450Z      M
# 2    2023-02-07T05:57:29.233Z      F
# 3    2023-02-07T06:04:39.836Z      M
# 4    2023-02-07T07:05:14.605Z      M
#
#                                          interests is_verified  status  \
# _id
# 0    Art & Craft,Bollywood,Comedy,Design,Badminton        True    True
# 1        Singing,Writing,Dancing,Mountains,Biryani        True    True
# 2      Badminton,Design,Writing,Open-Minded,Coffee        True    True
# 3          Singing,Cricket,Concerts,Vegetarian,Tea        True    True
# 4              Football,Gym,Biryani,Sci-fi,Cricket       False    True
#
#                     updatedAt who_to_date
# _id
# 0    2023-02-22T11:57:08.616Z           F
# 1    2023-02-21T18:07:44.286Z           F
# 2    2023-02-14T10:33:13.373Z           M
# 3    2023-02-26T20:28:11.956Z           F
# 4    2023-02-07T07:09:17.627Z           A

# %%
users_df["createdAtTime"]=users_df['createdAt']

users_df["updatedAtTime"]=users_df['updatedAt']

# %%
users_df['createdAt'] = pd.to_datetime(users_df['createdAt'])
# users_df['createdAtTime'] = pd.to_datetime(users_df.createdAtTime).dt.strftime('%H:%M:%S')

users_df['updatedAt'] = pd.to_datetime(users_df['updatedAt'])
# users_df['updatedAtTime'] = pd.to_datetime(users_df.updatedAtTime).dt.strftime('%H:%M:%S')

# %%
users_df.head()
# Out:
#                            createdAt gender  \
# _id
# 0   2023-02-07 05:23:18.004000+00:00      M
# 1   2023-02-07 05:44:15.450000+00:00      M
# 2   2023-02-07 05:57:29.233000+00:00      F
# 3   2023-02-07 06:04:39.836000+00:00      M
# 4   2023-02-07 07:05:14.605000+00:00      M
#
#                                          interests is_verified  status  \
# _id
# 0    Art & Craft,Bollywood,Comedy,Design,Badminton        True    True
# 1        Singing,Writing,Dancing,Mountains,Biryani        True    True
# 2      Badminton,Design,Writing,Open-Minded,Coffee        True    True
# 3          Singing,Cricket,Concerts,Vegetarian,Tea        True    True
# 4              Football,Gym,Biryani,Sci-fi,Cricket       False    True
#
#                            updatedAt who_to_date             createdAtTime  \
# _id
# 0   2023-02-22 11:57:08.616000+00:00           F  2023-02-07T05:23:18.004Z
# 1   2023-02-21 18:07:44.286000+00:00           F  2023-02-07T05:44:15.450Z
# 2   2023-02-14 10:33:13.373000+00:00           M  2023-02-07T05:57:29.233Z
# 3   2023-02-26 20:28:11.956000+00:00           F  2023-02-07T06:04:39.836Z
# 4   2023-02-07 07:09:17.627000+00:00           A  2023-02-07T07:05:14.605Z
#
#                 updatedAtTime
# _id
# 0    2023-02-22T11:57:08.616Z
# 1    2023-02-21T18:07:44.286Z
# 2    2023-02-14T10:33:13.373Z
# 3    2023-02-26T20:28:11.956Z
# 4    2023-02-07T07:09:17.627Z

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 993 entries, 0 to 1404
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   createdAt      993 non-null    datetime64[ns, UTC]
#  1   gender         993 non-null    object
#  2   interests      993 non-null    object
#  3   is_verified    993 non-null    object
#  4   status         993 non-null    bool
#  5   updatedAt      993 non-null    datetime64[ns, UTC]
#  6   who_to_date    993 non-null    object
#  7   createdAtTime  993 non-null    object
#  8   updatedAtTime  993 non-null    object
# dtypes: bool(1), datetime64[ns, UTC](2), object(6)
# memory usage: 70.8+ KB

# %%
user=users_df.sort_values(by=["createdAt"],ascending =True)
user
# Out:
#                             createdAt gender  \
# _id
# 0    2023-02-07 05:23:18.004000+00:00      M
# 1    2023-02-07 05:44:15.450000+00:00      M
# 2    2023-02-07 05:57:29.233000+00:00      F
# 3    2023-02-07 06:04:39.836000+00:00      M
# 4    2023-02-07 07:05:14.605000+00:00      M
# ...                               ...    ...
# 1400 2023-03-03 09:53:01.297000+00:00      M
# 1401 2023-03-03 12:43:15.149000+00:00      M
# 1402 2023-03-03 12:43:15.633000+00:00      M
# 1403 2023-03-03 16:12:31.677000+00:00      M
# 1404 2023-03-03 17:52:52.405000+00:00      M
#
#                                           interests is_verified  status  \
# _id
# 0     Art & Craft,Bollywood,Comedy,Design,Badminton        True    True
# 1         Singing,Writing,Dancing,Mountains,Biryani        True    True
# 2       Badminton,Design,Writing,Open-Minded,Coffee        True    True
# 3           Singing,Cricket,Concerts,Vegetarian,Tea        True    True
# 4               Football,Gym,Biryani,Sci-fi,Cricket       False    True
# ...                                             ...         ...     ...
# 1400                    Documentaries,Reels,Dancing       False    True
# 1401                                Rock,Vegetarian       False    True
# 1402          Bollywood,EDM,Coffee,Football,Biryani       False    True
# 1403                                                      False    True
# 1404          Running,Swimming,Stand Up,Biryani,EDM       False    True
#
#                             updatedAt who_to_date             createdAtTime  \
# _id
# 0    2023-02-22 11:57:08.616000+00:00           F  2023-02-07T05:23:18.004Z
# 1    2023-02-21 18:07:44.286000+00:00           F  2023-02-07T05:44:15.450Z
# 2    2023-02-14 10:33:13.373000+00:00           M  2023-02-07T05:57:29.233Z
# 3    2023-02-26 20:28:11.956000+00:00           F  2023-02-07T06:04:39.836Z
# 4    2023-02-07 07:09:17.627000+00:00           A  2023-02-07T07:05:14.605Z
# ...                               ...         ...                       ...
# 1400 2023-03-03 09:58:15.338000+00:00           F  2023-03-03T09:53:01.297Z
# 1401 2023-03-03 15:30:05.813000+00:00           F  2023-03-03T12:43:15.149Z
# 1402 2023-03-03 15:10:17.314000+00:00           F  2023-03-03T12:43:15.633Z
# 1403 2023-03-03 16:22:51.150000+00:00           F  2023-03-03T16:12:31.677Z
# 1404 2023-03-03 17:57:27.400000+00:00           F  2023-03-03T17:52:52.405Z
#
#                  updatedAtTime
# _id
# 0     2023-02-22T11:57:08.616Z
# 1     2023-02-21T18:07:44.286Z
# 2     2023-02-14T10:33:13.373Z
# 3     2023-02-26T20:28:11.956Z
# 4     2023-02-07T07:09:17.627Z
# ...                        ...
# 1400  2023-03-03T09:58:15.338Z
# 1401  2023-03-03T15:30:05.813Z
# 1402  2023-03-03T15:10:17.314Z
# 1403  2023-03-03T16:22:51.150Z
# 1404  2023-03-03T17:57:27.400Z
#
# [993 rows x 9 columns]
